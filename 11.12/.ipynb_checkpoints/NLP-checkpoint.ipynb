# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
#Run Only once
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
text="Hello! This is an Example Showing, how Text Pre Processing works better"
print("Original Text:",text)
# Out:
# Original Text: Hello! This is an Example Showing, how Text Pre Processing works better

# %%
text=text.lower()
print("After Lowercasing:",text)
# Out:
# After Lowercasing: hello! this is an example showing, how text pre processing works better

# %%
text=text.translate(str.maketrans('', '',string.punctuation))
print("After Removing Punctuation:",text)
# Out:
# After Removing Punctuation: hello this is an example showing how text pre processing works better

# %%
tokens=word_tokenize(text)
print("After Tokenization:",tokens)
# Out:
# After Tokenization: ['hello', 'this', 'is', 'an', 'example', 'showing', 'how', 'text', 'pre', 'processing', 'works', 'better']

# %%
stop_words=set(stopwords.words('english'))
filtered_tokens=[word for word in tokens if word not in stop_words]
print("After Removing Stopwords ; ",filtered_tokens)
# Out:
# After Removing Stopwords ;  ['hello', 'example', 'showing', 'text', 'pre', 'processing', 'works', 'better']

# %%
stemmer=PorterStemmer()
stemmed_word=[stemmer.stem(word) for word in filtered_tokens]
print("After Stemming:",stemmed_word)
# Out:
# After Stemming: ['hello', 'exampl', 'show', 'text', 'pre', 'process', 'work', 'better']

# %%
lemmatizer=WordNetLemmatizer()
lemmatized_words=[lemmatizer.lemmatize(word) for word in filtered_tokens]
print("After Lemmatization:",lemmatized_words)
# Out:
# After Lemmatization: ['hello', 'example', 'showing', 'text', 'pre', 'processing', 'work', 'better']
